# %% [markdown]
# The movie reviews website was very happy with your deliverable for the previous assignment and now they have a new request for you.The previous consultant had created a chart for them which is illustrated on the next slide. However the Python code used to create the diagram has since been lost and cannot be recovered. Your task is to come up with the code that will re-create the same chart making it look as close as possible to the originalA new dataset has been supplied.

# %%
import pandas as pd
import os
os.getcwd()

from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

movies = pd.read_csv('S6-Homework-Dataset.csv')
movies.columns=['WeekDay', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'AdjustedGrossMillion', 'BudgetMillion', 'GrossMillion',
       'IMDbRating', 'MovieLensRating', 'OverseasMillion', 'OverseasPct',
       'ProfitMillion', 'ProfitPct', 'RuntimeMin', 'USMillion',
       'GrossPctUS']

# %%
movies[(movies.Genre=='action') | (movies.Genre=='comedy') | (movies.Genre=='adventure') | (movies.Genre=='animation') | (movies.Genre=='drama')]
# Out:
#        WeekDay                                Director      Genre  \
# 0       Friday                               Brad Bird     action
# 1       Friday                             Scott Waugh     action
# 2       Friday                          Patrick Hughes     action
# 3       Friday                 Phil Lord, Chris Miller     comedy
# 4       Friday                         Roland Emmerich     action
# ..         ...                                     ...        ...
# 600     Friday                        Steven Spielberg  adventure
# 602    Tuesday                       Richard Fleischer  adventure
# 604  Wednesday                            George Lucas     action
# 606  Wednesday                           James Cameron      drama
# 607     Friday  George Cukor, Victor Fleming, Sam Wood      drama
#
#                       MovieTitle ReleaseDate               Studio  \
# 0                   Tomorrowland  22/05/2015  Buena Vista Studios
# ...

# %%
# y = gross pct US
# x = genre
# Box plot
# legend
sns.set_style('darkgrid')
plotData = movies[( \
                movies.Genre=='action') \
                | (movies.Genre=='comedy') \
                | (movies.Genre=='adventure') \
                | (movies.Genre=='animation') \
                | (movies.Genre=='drama')][ \
                    (movies.Studio =='Buena Vista Studios') \
                    | (movies.Studio == 'Sony') \
                    | (movies.Studio == 'Universal') \
                    | (movies.Studio == 'WB') \
                    | (movies.Studio == 'Paramount Pictures') \
                    | (movies.Studio == 'Fox') \
                    ]
                
fig,ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
box = sns.boxplot(data=plotData, x="Genre", y="GrossPctUS", showfliers=False, order=['action','comedy','adventure','animation','drama'], ax=ax, color='Lightgray', boxprops = {"alpha":0.8})
strip = sns.stripplot(data=plotData, x="Genre", y="GrossPctUS", hue="Studio", hue_order = ['Buena Vista Studios', 'Sony','Universal','WB','Paramount Pictures', 'Fox'], palette='deep', ax=ax, size=10, alpha=.8)
ax.set_yticks(np.arange(0,90,20))

plt.title("Domestic Gross % by Genre", fontsize=28, color="Black", fontname="DejaVu Sans")
plt.ylabel("Gross % US", fontsize=20, color="Black")
plt.xlabel("Genre", fontsize=20, color="Black")
plt.yticks(fontsize=16 )
# plt.xticks(fontsize=18, minor = True)
plt.legend(prop = {'size':12}, loc='upper left', bbox_to_anchor=(1, 1), edgecolor='White', facecolor='White')
plt.show()

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]
